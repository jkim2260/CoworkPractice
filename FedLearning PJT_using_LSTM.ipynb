# %%
import pandas as pd
import matplotlib.pyplot as plt


data = pd.read_csv('C:/Research/537PJT/Ecobee_1week_sample.csv')
#print(data)
plt.plot(data['DateTime'], data['Thermostat_Temperature'])
# Out:
#                                   ?.Identifier State        DateTime HvacMode  \
# 0     0856d074b5403f48da22b8296fd47abfdd641283    CA   9/1/2017 0:00     cool
# 1     0856d074b5403f48da22b8296fd47abfdd641283    CA   9/1/2017 0:05     cool
# 2     0856d074b5403f48da22b8296fd47abfdd641283    CA   9/1/2017 0:10     cool
# 3     0856d074b5403f48da22b8296fd47abfdd641283    CA   9/1/2017 0:15     cool
# 4     0856d074b5403f48da22b8296fd47abfdd641283    CA   9/1/2017 0:20     cool
# ...                                        ...   ...             ...      ...
# 2011  0856d074b5403f48da22b8296fd47abfdd641283    CA  9/7/2017 23:35     cool
# 2012  0856d074b5403f48da22b8296fd47abfdd641283    CA  9/7/2017 23:40     cool
# 2013  0856d074b5403f48da22b8296fd47abfdd641283    CA  9/7/2017 23:45     cool
# 2014  0856d074b5403f48da22b8296fd47abfdd641283    CA  9/7/2017 23:50     cool
# 2015  0856d074b5403f48da22b8296fd47abfdd641283    CA  9/7/2017 23:55     cool
#
# ...
